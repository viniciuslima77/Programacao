# %% [markdown]
# <a href="https://colab.research.google.com/github/viniciuslima77/Programacao/blob/main/Aula_10_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Estrutura de Decisão

if

elif

else

# %%
numero = 5
numero01 = int (input ("digite um número:"))

if numero > numero01:
  print (f"{numero} é maior que {numero01}")

else:
  print (f"{numero} é menor que {numero01}")
# Out:
# digite um número:4
# 5 é maior que 4

# %%
# Escrever um programa que leia dois números e retorne se eles são iguais

a = int (input ("digite um número:"))
b = int (input ("digite um número:"))

if a > b:


else:
    print (f"{a} é menor que {b}")
# Out:
#   File "/tmp/ipykernel_1346/1746799043.py", line 9
#     else:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 6

# %%
# Escrever um programa que leia as notas dos quatro bimestres e o nome do aluno, calcule a média.

# média menor que 5 - reprovado
# média menor que 7 - recuperação
# média maior que 7 - aprovado

nome = str (input ("Digite seu nome: "))

nota1 = float (input("digite a nota do 1° bimestre: "))
nota2 = float (input("digite a nota do 2° bimestre: "))
nota3 = float (input("digite a nota do 3° bimestre:"))
nota4 + float (input("digite a nota do 4° bimestre: "))

media = (nota1 + nota2 + nota3 + nota4) / 4

if nédia > 7
print f"{nome} sua média é: {média} você foi aprovado"
