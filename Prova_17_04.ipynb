# %% [markdown]
# <a href="https://colab.research.google.com/github/viniciuslima77/Programacao/blob/main/Prova_17_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Par ou ímpar
# Peça um número ao usuário e informe se ele é par ou ímpar.

# %%
numero01 = int (input ("Digite o número: "))

if numero01 % 2 == 0:
    print ("esse número é par")
else:
    print ("esse número é impar")
# Out:
# Digite o número: 55
# esse número é impar

# %% [markdown]
# 2. Maior de dois números
# Solicite dois números e mostre qual é o maior (ou se são iguais).

# %%
numero01 = int (input ("digite um numero: "))
numero02 = int (input ("digite outro numero: "))

if numero01 > numero02:
    print (f"{numero01} é maior que {numero02}")

elif numero02 > numero01:
    print (f"{numero02} é maior que {numero01}")
else:
    print ("esses números são iguais")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4082/301451988.py in <cell line: 0>()
# ----> 1 numero01 = int (input ("digite um numero: "))
#       2 numero02 = int (input ("digite outro numero: "))
#       3
#       4 if numero01 > numero02:
#       5     print (f"{numero01} é maior que {numero02}")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# 3. Aprovação de aluno
# Peça a nota de um aluno e informe:
#
# o Aprovado (nota ≥ 7)
#
# o Recuperação (5 ≤ nota &lt; 7)
#
# o Reprovado (nota &lt; 5)

# %%
nota = float (input ("digite a sua nota:"))

if nota >= 7:
  print("Parabéns, você foi aprovado!")
elif nota >= 5 and nota < 7:
  print("Você ficou de recuperação.")
else:
  print("Você foi reprovado.")

# %% [markdown]
# 4. Classificação de idade
# Receba a idade e classifique:
#
# o Criança (0–12)
#
# o Adolescente (13–17)
#
# o Adulto (18–59)
#
# o Idoso (60+)

# %%
idade = int (input ("digite sua idade: "))

if 12 > idade > 0:
  print ("Você é criança")
elif 17 > idade > 13:
  print ("Você é adolescente")
elif 59 > idade > 18:
  print ("Você é adulto")
else:
  print ("Você é idoso")

# %% [markdown]
# Senha correta
# Defina uma senha fixa no código. Peça ao usuário para digitar e informe se está
# correta ou incorreta.

# %%
senhacorreta = 456321

senha = int (input ("digite a senha: "))

if senha == 456321:
  print ("senha correta")
else:
  print ("senha incorreta")
# Out:
# digite a senha: 3232
# senha incorreta

# %% [markdown]
# Positivo, negativo ou zero
# Peça um número e diga se ele é positivo, negativo ou zero.

# %%
numero = int(input("Digite um número: "))

if numero > 0:
    print("O número é positivo.")
elif numero < 0:
    print("O número é negativo.")
else:
    print("O número é zero.")

# %% [markdown]
# 7. Calculadora simples
# Peça dois números e uma operação (+, -, *, /). Use if/elif para calcular o
# resultado.

# %%
numero01 = int (input ("digite um numero: "))
numero02 = int (input ("digite outro numero: "))
print ("operações disponíveis:")
print ("adição = +")
print ("subtração = -")
print ("multiplicação = *")
print ("divisão = /")

operacao = input ("digite a operação: ")


if operacao == "+":
  print (numero01 + numero02)
elif operacao == "-":
  print (numero01 - numero02)
elif operacao == "*":
  print (numero01 * numero02)
elif operacao == "/":
  print (numero01 / numero02)
# Out:
# digite um numero: 64
# digite outro numero: 34
# operações disponíveis:
# adição = +
# subtração = -
# multiplicação = *
# divisão = /
# digite a operação: /
# 1.8823529411764706

# %% [markdown]
# Dia da semana
# Peça um número de 1 a 7 e mostre o dia correspondente (ex: 1 = domingo).

# %%
print ("1 = domingo")
print ("2 = segunda-feira")
print ("3 = terça-feira")
print ("4 = quarta-feira")
print ("5 = quinta-feira")
print ("6 = sexta-feira")
print ("7 = sábado")

dia = int (input ("digite o dia da semana: "))

if dia == 1:
  print ("domingo")
elif dia == 2:
  print ("segunda-feira")
elif dia == 3:
  print ("terça-feira")
elif dia == 4:
  print ("quarta-feira")
elif dia == 5:
  print ("quinta-feira")
elif dia == 6:
  print ("sexta-feira")
elif dia == 7:
  print ("sábado")
else:
  print ("insira um dia válido")

# %% [markdown]
# Ano bissexto
# Solicite um ano e informe se ele é bissexto ou não.

# %%
ano = int(input("Digite um ano: "))

if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
    print(f"O ano {ano} é bissexto.")
else:
    print(f"O ano {ano} não é bissexto.")

# %% [markdown]
# 10. Desconto em compras
# Peça o valor de uma compra:
#
#  ≥ 100: 10% de desconto
#
#  ≥ 50 e &lt; 100: 5% de desconto
#
#  &lt; 50: sem desconto

# %%
compra = float (input ("digite o valor da compra: "))
if compra >= 100:
  print ("você ganhou 10% de desconto")
  print (f" o total agora é: R$ {compra - (compra * 0.10)}")
elif 100 > compra >= 50:
  print ("você ganhou 5% de desconto")
  print (f" o total agora é: R$ {compra - (compra * 0.05)}")
else:
  print ("você não ganhou desconto")
